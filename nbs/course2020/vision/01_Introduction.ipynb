# %% [markdown]
# # Lesson 1 - Introduction

# %% [markdown]
# ## Lesson Video:

# %%
#hide_input
from IPython.lib.display import YouTubeVideo
YouTubeVideo('bw4PRyxa-y4')

# %% [markdown]
# ![](https://github.com/muellerzr/Practical-Deep-Learning-for-Coders-2.0/blob/master/walkwithfastai.png?raw=true)
#
# ## About this course/study group:
# * It's a hybrid
# * Like Practical Deep Learning for Coders but many bonuses
# * Spans 2-3 hours depending on who stays with 1-1.5 hour lectures
#
# ## About Me:
# * Been doing fastai for 1.5 years
# * A few projects (some involving fastai, some not)
# * University undergraduate, Software Design and Development with a minor in ES
#
# ## Why did I make this?
# * Make fastai accessable to Undergraduates at my school (University of West Florida)
# * We both learn
# * Techniques not mentioned in the course

# %% [markdown]
# ## Course Format:
#
# Below you will find links to all the lessons and their notebooks in this course. To open up and use them, simply click the "Open in Colab" button at the top of each
#
# ## Vision Block:
#
# * Lesson 1:
#   * [Introduction](https://walkwithfastai.com/Introduction)
#   * [Pets and the High Level API](https://walkwithfastai.com/Pets)
#   * [Image CLassification with a Custom Dataset](https://walkwithfastai.com/Custom)
# * Lesson 2:
#   * [Low-Level API with MNIST and Building Models](https://walkwithfastai.com/MNIST)
#   * [Stochastic Gradient Descent](https://walkwithfastai.com/SGD)
#   * [Deployment](https://walkwithfastai.com/Deployment)
# * Lesson 3:
#   * [Multi-Label Classification](https://walkwithfastai.com/Multi_Label)
#   * [Recognizing Unknown Images (or the Unknown Label problem)](https://walkwithfastai.com/Unknown_Labels)
#   * [Cross Validation and Ensembling](https://walkwithfastai.com/Cross_Validation)
#   * [The Internal API of fastai](https://walkwithfastai.com/Internal_API_Walkthrough)
# * Lesson 4:
#   * [Image Segmentation](https://walkwithfastai.com/Segmentation)
#   * [ImageWoof and Exploring SOTA in fastai](https://walkwithfastai.com/ImageWoof)
#   * [Debugging with the DataBlock](https://walkwithfastai.com/DBlock_Summary)
# * Lesson 5:
#   * [Style Transfer](https://walkwithfastai.com/Style_Transfer)
#   * [Deployment Continued](https://walkwithfastai.com/Inference_Server)
#   * [EfficientNet and Custom Weights](https://walkwithfastai.com/EfficientNet_and_Custom_Weights)
# * Lesson 6:
#   * [Keypoint Regression](https://walkwithfastai.com/Keypoint_Regression)
#   * [Hybridizing Models](https://walkwithfastai.com/Hybridizing_Models)
#   * [Object Detection](https://walkwithfastai.com/Object_Detection)
#   * [Multimodal Learning with Bengali.AI](https://walkwithfastai.com/Multimodal_Head_and_Kaggle)
# * Lesson 7:
#   * [Super Resolution](https://walkwithfastai.com/Super_Resolution)
#   * [Siamese](https://walkwithfastai.com/Siamese)
#   * [Audio](https://walkwithfastai.com/Audio)

# %% [markdown]
# ## Tabular Block:
#
# * Lesson 1:
#   * [Introduction to Pandas](https://walkwithfastai.com/Pandas)
#   * [The Tabular API with Binary Classification](https://walkwithfastai.com/Adults)
# * Lesson 2:
#   * [Regression and Permutation Importance](https://walkwithfastai.com/Regression_and_Permutation_Importance)
#   * [Ensembling with Other Libraries](https://walkwithfastai.com/Ensembling)
#   * [Bayesian Optimization](https://walkwithfastai.com/Bayesian_Optimization)
# * Lesson 3:
#   * [SHAP and fastinference](https://walkwithfastai.com/SHAP)
#   * [ClassConfusion and fastinference](https://walkwithfastai.com/ClassConfusion)
#   * [Doing Research](https://walkwithfastai.com/Research)
# * Lesson 4:
#   * [TabNet](https://walkwithfastai.com/TabNet)
#   * [Time Series](https://walkwithfastai.com/TimeSeries)

# %% [markdown]
# ## Requirements:
#
# * A Google account to use Google Colaboratory (what I am in right now)
# * A Paperspace account for Natural Language Processing

# %% [markdown]
# ## Communication
# * Key to making study groups work!
# * We have a dedicated mega-thread on the fastai forums [here](https://forums.fast.ai/t/a-walk-with-fastai-study-group-and-online-lectures-megathread/59929) for us to use!
# * No question is too stupid!

# %% [markdown]
# ## Environment setup
#
# Google Colaboratory - Free GPU's
#
# Go to [here](colab.research.google.com) to start using it.

# %% [markdown]
# File -> Open notebook

# %% [markdown]
# ![](https://i.imgur.com/pGCkS9G.png)

# %% [markdown]
# Select from GitHub and use the following URL: muellerzr/A-walk-with-fastai

# %% [markdown]
# ![](https://i.imgur.com/9O1LMZt.png)

# %% [markdown]
# Choose open in a new tab

# %% [markdown]
# ![](https://i.imgur.com/NuL67k9.png)

# %% [markdown]
# And now your screen looks similar to below! (With what I am using instead)

# %% [markdown]
# ![alt text](https://i.imgur.com/n4mQ2qj.png)

# %% [markdown]
# ## Changing our processer to a GPU

# %% [markdown]
# * 'Runtime'
# * 'Change runtime type'
# * 'Runtime type' should be 'Python 3'
# * 'Hardware accelerator' should be 'GPU'

# %% [markdown]
# ## Initial Run Warning (For pulling from GitHub)

# %% [markdown]
# ***If you get a pop up saying 'Warning: This notebook was not authored by Google,' check 'Reset all runtimes before running' and click 'Run Anyway'***

# %% [markdown]
# ![alt text](https://course.fast.ai/images/colab/02.png)

# %% [markdown]
# ## Saving your work
#
# For now this will just save the notebook on their cloud, we will look next week how to utilize your Google Drives!

# %% [markdown]
# ![alt text](https://course.fast.ai/images/colab/09.png)
